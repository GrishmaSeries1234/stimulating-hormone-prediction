# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',None) #for showing data
pd.set_option('display.max_rows',None)

# %%
df=pd.read_excel('ML xl sheet 100  records mini.xlsx')

# %%
df.head()
# Out:
#         Patient Name  Age  Gender                 Date  Disease  \
# 0  M.Nagendra Kumari   20  Female  2021-01-06 00:00:00  Thyroid
# 1        K.Rupavathi   20  Female  2021-06-10 00:00:00  Thyroid
# 2          P Suvarna   28  Female  2021-06-30 00:00:00  Thyroid
# 3          P Saradha   52  Female  2021-06-19 00:00:00  Thyroid
# 4     P Aswin Kumar    35    Male  2021-06-30 00:00:00  Thyroid
#
#   Biological Reference      Results
# 0     0.35 -5.50 mg/dl  2.15 UIU/ml
# 1     0.35 -5.50 mg/dl  0.32 UIU/ml
# 2     0.35 -5.50 mg/dl  2.15 UIU/ml
# 3     0.35 -5.50 mg/dl  0.89 UIU/ml
# 4     0.35 -5.50 mg/dl  3.21 UIU/ml

# %%
df
# Out:
#               Patient Name  Age  Gender                 Date     Disease  \
# 0        M.Nagendra Kumari   20  Female  2021-01-06 00:00:00     Thyroid
# 1              K.Rupavathi   20  Female  2021-06-10 00:00:00     Thyroid
# 2                P Suvarna   28  Female  2021-06-30 00:00:00     Thyroid
# 3                P Saradha   52  Female  2021-06-19 00:00:00     Thyroid
# 4           P Aswin Kumar    35    Male  2021-06-30 00:00:00     Thyroid
# 5               S Lavanya    26  Female  2021-06-01 00:00:00     Thyroid
# 6                  S Durga   45  Female  2021-06-01 00:00:00     Thyroid
# 7           S Surya Kumari   28  Female  2021-06-01 00:00:00     Thyroid
# 8                K.Meghana   17  Female  2021-06-01 00:00:00     Thyroid
# 9             Ch. Harshini   14  Female  2021-06-03 00:00:00     Thyroid
# 10            M.Arun Kumar   30    Male  2021-06-03 00:00:00     Thyroid
# 11                T.Suguna   45  Female  2021-06-06 00:00:00     Thyroid
# ...

# %% [markdown]
# #Univarite analysis

# %%
df["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
plt.hist(df['Age'])
# Out:
# (array([ 5.,  8., 16., 10., 12., 18., 12.,  6.,  9.,  4.]),
#  array([12. , 18.1, 24.2, 30.3, 36.4, 42.5, 48.6, 54.7, 60.8, 66.9, 73. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.countplot(df['Disease'])
# Out:
# <Axes: xlabel='count', ylabel='Disease'>

# %% [markdown]
# Bivariate analysis

# %%
sns.barplot(df,x='Age',y='Disease')
# Out:
# <Axes: xlabel='Age', ylabel='Disease'>

# %% [markdown]
# multivariate analysis

# %%
sns.pairplot(df)

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
#Checking Duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
#checkin missing values
df.isnull().sum()
# Out:
#  Patient Name           0
# Age                     0
# Gender                  0
# Date                    0
# Disease                 0
# Biological Reference    0
# Results                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0    Patient Name         100 non-null    object
#  1   Age                   100 non-null    int64
#  2   Gender                100 non-null    object
#  3   Date                  100 non-null    object
#  4   Disease               100 non-null    object
#  5   Biological Reference  100 non-null    object
#  6   Results               100 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.6+ KB

# %%
df.describe(include='object')
# Out:
#           Patient Name  Gender                 Date     Disease  \
# count              100     100                  100         100
# unique              97       2                   43           3
# top     V.Durga Prasad  Female  2021-06-01 00:00:00  Creatinine
# freq                 3      52                   20          51
#
#        Biological Reference    Results
# count                   100        100
# unique                    7         51
# top           0.5-1.2 mg/dl  0.7 mg/dl
# freq                     51         12

# %%
df.head()
# Out:
#         Patient Name  Age  Gender                 Date  Disease  \
# 0  M.Nagendra Kumari   20  Female  2021-01-06 00:00:00  Thyroid
# 1        K.Rupavathi   20  Female  2021-06-10 00:00:00  Thyroid
# 2          P Suvarna   28  Female  2021-06-30 00:00:00  Thyroid
# 3          P Saradha   52  Female  2021-06-19 00:00:00  Thyroid
# 4     P Aswin Kumar    35    Male  2021-06-30 00:00:00  Thyroid
#
#   Biological Reference      Results
# 0     0.35 -5.50 mg/dl  2.15 UIU/ml
# 1     0.35 -5.50 mg/dl  0.32 UIU/ml
# 2     0.35 -5.50 mg/dl  2.15 UIU/ml
# 3     0.35 -5.50 mg/dl  0.89 UIU/ml
# 4     0.35 -5.50 mg/dl  3.21 UIU/ml

# %%
df['Biological Reference'].str.strip()
# Out:
# 0     0.35 -5.50 mg/dl
# 1     0.35 -5.50 mg/dl
# 2     0.35 -5.50 mg/dl
# 3     0.35 -5.50 mg/dl
# 4     0.35 -5.50 mg/dl
# 5     0.35 -5.50 mg/dl
# 6     0.35 -5.50 mg/dl
# 7     0.35 -5.50 mg/dl
# 8     0.38 -5.80 mg/dl
# 9     0.38 -5.80 mg/dl
# 10    0.35 -5.50 mg/dl
# 11    0.35 -5.50 mg/dl
# 12    0.35 -5.50 mg/dl
# 13    0.35 -5.50 mg/dl
# 14    0.35 -5.50 mg/dl
# 15    0.35 -5.50 mg/dl
# 16    0.35 -5.50 mg/dl
# 17    0.35 -5.50 mg/dl
# 18    0.35 -5.50 mg/dl
# 19    0.35 -5.50 mg/dl
# 20    0.35 -5.50 mg/dl
# 21    0.35 -5.50 mg/dl
# 22    0.35 -5.50 mg/dl
# 23    0.35 -5.50 mg/dl
# 24    0.35 -5.50 mg/dl
# 25    0.38 -5.80 mg/dl
# 26    0.35 -5.50 mg/dl
# 27     0.50-8.90 mg/dl
# 28     0.38-5.80 mg/dl
# 29     0.50-8.90 mg/dl
# 30    0.35 -5.50 mg/dl
# 31    0.35 -5.50 mg/dl
# 32    0.35 -5.50 mg/dl
# 33    0.35 -5.50 mg/dl
# 34    0.35 -5.50 mg/dl
# 35    0.35 -5.50 mg/dl
# 36       0.5-1.2 mg/dl
# 37       0.5-1.2 mg/dl
# 38       0.5-1.2 mg/dl
# 39       0.5-1.2 mg/dl
# ...

# %%
#Data cleaning
df["Biological_min"]=df['Biological Reference'].apply(lambda x:x.replace("mg/dl","")[0])

# %%
df['Biological_max']=df['Biological Reference'].apply(lambda x:x.replace("-","")[2])

# %%
df.head()
# Out:
#         Patient Name  Age  Gender                 Date  Disease  \
# 0  M.Nagendra Kumari   20  Female  2021-01-06 00:00:00  Thyroid
# 1        K.Rupavathi   20  Female  2021-06-10 00:00:00  Thyroid
# 2          P Suvarna   28  Female  2021-06-30 00:00:00  Thyroid
# 3          P Saradha   52  Female  2021-06-19 00:00:00  Thyroid
# 4     P Aswin Kumar    35    Male  2021-06-30 00:00:00  Thyroid
#
#   Biological Reference      Results Biological_min Biological_max
# 0     0.35 -5.50 mg/dl  2.15 UIU/ml              0              3
# 1     0.35 -5.50 mg/dl  0.32 UIU/ml              0              3
# 2     0.35 -5.50 mg/dl  2.15 UIU/ml              0              3
# 3     0.35 -5.50 mg/dl  0.89 UIU/ml              0              3
# 4     0.35 -5.50 mg/dl  3.21 UIU/ml              0              3

# %%
df
# Out:
#               Patient Name  Age  Gender                 Date     Disease  \
# 0        M.Nagendra Kumari   20  Female  2021-01-06 00:00:00     Thyroid
# 1              K.Rupavathi   20  Female  2021-06-10 00:00:00     Thyroid
# 2                P Suvarna   28  Female  2021-06-30 00:00:00     Thyroid
# 3                P Saradha   52  Female  2021-06-19 00:00:00     Thyroid
# 4           P Aswin Kumar    35    Male  2021-06-30 00:00:00     Thyroid
# 5               S Lavanya    26  Female  2021-06-01 00:00:00     Thyroid
# 6                  S Durga   45  Female  2021-06-01 00:00:00     Thyroid
# 7           S Surya Kumari   28  Female  2021-06-01 00:00:00     Thyroid
# 8                K.Meghana   17  Female  2021-06-01 00:00:00     Thyroid
# 9             Ch. Harshini   14  Female  2021-06-03 00:00:00     Thyroid
# 10            M.Arun Kumar   30    Male  2021-06-03 00:00:00     Thyroid
# 11                T.Suguna   45  Female  2021-06-06 00:00:00     Thyroid
# ...

# %%
df['Results']=df['Results'].apply(lambda x:x.replace('UIU/ml',""))

# %%
df['Results']=df['Results'].apply(lambda x:x.replace("mg/dl",""))

# %%
df
# Out:
#               Patient Name  Age  Gender                 Date     Disease  \
# 0        M.Nagendra Kumari   20  Female  2021-01-06 00:00:00     Thyroid
# 1              K.Rupavathi   20  Female  2021-06-10 00:00:00     Thyroid
# 2                P Suvarna   28  Female  2021-06-30 00:00:00     Thyroid
# 3                P Saradha   52  Female  2021-06-19 00:00:00     Thyroid
# 4           P Aswin Kumar    35    Male  2021-06-30 00:00:00     Thyroid
# 5               S Lavanya    26  Female  2021-06-01 00:00:00     Thyroid
# 6                  S Durga   45  Female  2021-06-01 00:00:00     Thyroid
# 7           S Surya Kumari   28  Female  2021-06-01 00:00:00     Thyroid
# 8                K.Meghana   17  Female  2021-06-01 00:00:00     Thyroid
# 9             Ch. Harshini   14  Female  2021-06-03 00:00:00     Thyroid
# 10            M.Arun Kumar   30    Male  2021-06-03 00:00:00     Thyroid
# 11                T.Suguna   45  Female  2021-06-06 00:00:00     Thyroid
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0    Patient Name         100 non-null    object
#  1   Age                   100 non-null    int64
#  2   Gender                100 non-null    object
#  3   Date                  100 non-null    object
#  4   Disease               100 non-null    object
#  5   Biological Reference  100 non-null    object
#  6   Results               100 non-null    object
#  7   Biological_min        100 non-null    object
#  8   Biological_max        100 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 7.2+ KB

# %%
df['Results']=df['Results'].astype(float)
df['Biological_min']=df['Biological_min'].astype(float)
df['Biological_max']=df['Biological_max'].astype(float)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
def bining(gender):
    if gender=='Female':
        return 0
    else:
        return 1
df['Gender']=df['Gender'].apply(bining)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0    Patient Name         100 non-null    object
#  1   Age                   100 non-null    int64
#  2   Gender                100 non-null    int64
#  3   Date                  100 non-null    object
#  4   Disease               100 non-null    object
#  5   Biological Reference  100 non-null    object
#  6   Results               100 non-null    float64
#  7   Biological_min        100 non-null    float64
#  8   Biological_max        100 non-null    float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 7.2+ KB

# %%
#dropping the columns Date and Biological refrence
df.drop(columns=['Date','Biological Reference'],axis=1,inplace=True)

# %%
#from sklearn.preprocessing import OneHotEncoder
#encoder=OneHotEncoder()
#encoder.fit_transform(df['Disease'])
#df=pd.get_dummies(df,columns=['Disease'],drop_first=True)

# %%
#def glucose(disease):
#   if disease=="True":
#       return 1
#
#   else:
#       return 0
#f['Disease_Glucose']=df['Disease_Glucose'].apply(glucose)
#

# %%
df
# Out:
#               Patient Name  Age  Gender     Disease  Results  Biological_min  \
# 0        M.Nagendra Kumari   20       0     Thyroid     2.15             0.0
# 1              K.Rupavathi   20       0     Thyroid     0.32             0.0
# 2                P Suvarna   28       0     Thyroid     2.15             0.0
# 3                P Saradha   52       0     Thyroid     0.89             0.0
# 4           P Aswin Kumar    35       1     Thyroid     3.21             0.0
# 5               S Lavanya    26       0     Thyroid     3.80             0.0
# 6                  S Durga   45       0     Thyroid     5.99             0.0
# 7           S Surya Kumari   28       0     Thyroid     2.04             0.0
# 8                K.Meghana   17       0     Thyroid     3.60             0.0
# 9             Ch. Harshini   14       0     Thyroid     5.64             0.0
# 10            M.Arun Kumar   30       1     Thyroid     0.40             0.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['Disease']=encoder.fit_transform(df['Disease'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0    Patient Name   100 non-null    object
#  1   Age             100 non-null    int64
#  2   Gender          100 non-null    int64
#  3   Disease         100 non-null    int32
#  4   Results         100 non-null    float64
#  5   Biological_min  100 non-null    float64
#  6   Biological_max  100 non-null    float64
# dtypes: float64(3), int32(1), int64(2), object(1)
# memory usage: 5.2+ KB

# %%
df.rename(columns={" Patient Name":"Patient"},inplace=True)

# %%
df.drop(columns=['Patient'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Age  Gender  Disease  Results  Biological_min  Biological_max
# 0   20       0        2     2.15             0.0             3.0
# 1   20       0        2     0.32             0.0             3.0
# 2   28       0        2     2.15             0.0             3.0
# 3   52       0        2     0.89             0.0             3.0
# 4   35       1        2     3.21             0.0             3.0

# %%
df.shape
# Out:
# (100, 6)

# %%
#creating the independent and the dependent feature
x=df.drop('Results',axis=1)
y=df['Results']

# %%
print(x.shape)
print(y.shape)
# Out:
# (100, 5)
# (100,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (80, 5)
# (20, 5)
# (80,)
# (20,)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
y_pred=reg.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.32913112215775053

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
ridge=Ridge()
ridge.fit(x_train,y_train)
# Out:
# Ridge()

# %%
y_pred1=ridge.predict(x_test)
r2_score(y_test,y_pred1)
# Out:
# 0.3340762168737724

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
# Out:
# Lasso()

# %%
y_pred2=lasso.predict(x_test)
r2_score(y_test,y_pred2)
# Out:
# 0.36243006854506987

# %%
plt.plot(y_test-y_pred)

# %%
plt.plot(y_test-y_pred1)

# %%
plt.plot(y_test-y_pred2)

# %%
from sklearn.tree import DecisionTreeRegressor
dreg=DecisionTreeRegressor(max_depth=2)
dreg.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
y_pred3=dreg.fit(x_train,y_train)

# %%
from sklearn.tree import plot_tree
plot_tree(dreg)
plt.show()

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [-0.16289411 -1.52908805 -0.20832335 22.27477379  1.16485912]
# 4.621656706985199

# %%
import pickle
pickle.dump(lasso,open("lasso.pkl","wb"))
pickle.dump(df,open("df.pkl","wb"))
